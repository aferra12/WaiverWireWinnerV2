# %%
import requests
import json

league_id = 760081598
year = 2025
#fantasy.espn.com/apis/v3/games/ffl/leagueHistory/:league_id?seasonId=:season
url = "https://lm-api-reads.fantasy.espn.com/apis/v3/games/flb/seasons/2024/segments/0/leagues/760081598"# + \
      #str(league_id) + "?seasonId=" + str(year)

r = requests.get(url,
                 cookies={"swid": "{DEF635BE-7DB6-462F-86E1-B1945753DC0A}",
                          "espn_s2": "AECruZRCXn0BHlCv%2BynVzxJbda4zDpJrXCBeezjIqOWuh21G%2F0p7xB%2BDKjMiyCR7pPjlyXyJfir%2FpoHZmwao%2Bksyh%2FBdJ0oPelLZDl%2BP8CJcF7evYbcW3A0KIdsJaTfh1YZWv%2FfzuC1PTXw3b8pMFpRaXgm8z0uh0GWqOSlnPewLcoOEHYL9R2swj64sOJrX3a9e4YwsvyH93OnFyMpPX8FKVS3Yb%2Brfelo2s2qZG855rZkAzPc9tyVMnURUoJH%2FTFG8sTs%2Bd9D8cuHfcUbWyD0VTYP39LNOH3%2BLBxTBLsi7mw%3D%3D"})

print(json.dumps(r.json(), indent=4))
# Out:
# {
#     "gameId": 2,
#     "id": 760081598,
#     "members": [
#         {
#             "displayName": "dillon5499657",
#             "id": "{2057C755-33FB-4511-913C-0EFD675E9990}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "Kyle64655",
#             "id": "{20B775B5-5DAB-4BE2-B775-B55DAB6BE219}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "ESPNFAN8886888",
#             "id": "{371C6056-332E-4B78-A748-A89028896967}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "ESPNFAN7590146634",
#             "id": "{412D7913-5D28-4A74-9F7C-092F3E53494F}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "smccmuffin",
#             "id": "{42821CD5-BA25-4673-9863-BD982302659E}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "nick_li",
#             "id": "{428DF1C6-B7AB-4A49-8DF1-C6B7AB0A497A}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "RickyBobby2323",
#             "id": "{46201D1F-9867-4D91-A571-50B3CE6A9107}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "ArenaStarz5",
#             "id": "{4A308EB8-0151-4519-BA50-4DE8F8BE47D6}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "ethanroth24",
#             "id": "{643CBCDA-3840-4DD6-BCBC-DA38404DD68F}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "ESPNFAN6143553015",
#             "id": "{65AD150C-B32C-4287-A731-35F5DEF5B065}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "RyanMcDonald123",
#             "id": "{692022BB-7549-4974-9FC6-3CFF1B45C1A3}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "C_festa23",
#             "id": "{854E312A-BC0C-4C3B-8E31-2ABC0C5C3BDE}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "tkb-ball6",
#             "id": "{93A4AA8F-16FC-4B87-9232-E7C8CC9BCAAC}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "espnfan2963139790",
#             "id": "{A1CF338A-E11B-4B2B-B007-6C4916705DCB}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "asacks20",
#             "id": "{B300EFB4-C4B0-4489-B223-2BBEC1C9457C}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "whitesox32396",
#             "id": "{B98F7BCE-BF36-4468-A2D3-CADAC71E27DA}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "jarcher724",
#             "id": "{BC3AB094-531B-4959-BAB0-94531B095973}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "AdamKohl14",
#             "id": "{BDE89EAD-5DD5-428C-A89E-AD5DD5928C31}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "johndonohue49",
#             "id": "{C7BA9315-FAE9-40EA-BA93-15FAE970EA9C}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "BP_114",
#             "id": "{D0F9919A-5E9C-418A-952D-9A13A733B299}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "jcarmi2302015",
#             "id": "{D4183711-9DEB-48B2-9D7F-79CA466CBF40}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "Nick Kohl XVII",
#             "id": "{D7A6ABB4-980B-4EB6-8D45-066061981C8C}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "Big Ang 24",
#             "id": "{DEF635BE-7DB6-462F-86E1-B1945753DC0A}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "JSchneidez",
#             "id": "{E8C79D7F-5460-4086-879D-7F54606086E5}",
#             "isLeagueManager": false
#         },
#         {
#             "displayName": "samiscool7268",
#             "id": "{F06FD2AD-EC9D-418A-AEA6-457067088308}",
#             "isLeagueManager": false
#         }
#     ],
#     "scoringPeriodId": 196,
#     "seasonId": 2024,
#     "segmentId": 0,
#     "settings": {
#         "name": "Hilltop Fantasy Baseball 11.0"
#     },
#     "status": {
#         "currentMatchupPeriod": 26,
#         "isActive": true,
#         "latestScoringPeriod": 196
#     },
#     "teams": [
#         {
#             "abbrev": "YODA",
#             "id": 1,
#             "owners": [
#                 "{46201D1F-9867-4D91-A571-50B3CE6A9107}"
#             ]
#         },
#         {
#             "abbrev": "MTCH",
#             "id": 18,
#             "owners": [
#                 "{428DF1C6-B7AB-4A49-8DF1-C6B7AB0A497A}"
#             ]
#         },
#         {
#             "abbrev": "908",
#             "id": 19,
#             "owners": [
#                 "{4A308EB8-0151-4519-BA50-4DE8F8BE47D6}",
#                 "{2057C755-33FB-4511-913C-0EFD675E9990}"
#             ]
#         },
#         {
#             "abbrev": "4SKN",
#             "id": 20,
#             "owners": [
#                 "{F06FD2AD-EC9D-418A-AEA6-457067088308}",
#                 "{D4183711-9DEB-48B2-9D7F-79CA466CBF40}"
#             ]
#         },
#         {
#             "abbrev": "COX",
#             "id": 21,
#             "owners": [
#                 "{DEF635BE-7DB6-462F-86E1-B1945753DC0A}"
#             ]
#         },
#         {
#             "abbrev": "OZU",
#             "id": 22,
#             "owners": [
#                 "{E8C79D7F-5460-4086-879D-7F54606086E5}"
#             ]
#         },
#         {
#             "abbrev": "SST",
#             "id": 23,
#             "owners": [
#                 "{A1CF338A-E11B-4B2B-B007-6C4916705DCB}"
#             ]
#         },
#         {
#             "abbrev": "WPG",
#             "id": 24,
#             "owners": [
#                 "{93A4AA8F-16FC-4B87-9232-E7C8CC9BCAAC}",
#                 "{C7BA9315-FAE9-40EA-BA93-15FAE970EA9C}"
#             ]
#         },
#         {
#             "abbrev": "AAT",
#             "id": 25,
#             "owners": [
#                 "{BDE89EAD-5DD5-428C-A89E-AD5DD5928C31}"
#             ]
#         },
#         {
#             "abbrev": "HOSE",
#             "id": 26,
#             "owners": [
#                 "{BC3AB094-531B-4959-BAB0-94531B095973}"
#             ]
#         },
#         {
#             "abbrev": "KREM",
#             "id": 27,
#             "owners": [
#                 "{D7A6ABB4-980B-4EB6-8D45-066061981C8C}"
#             ]
#         },
#         {
#             "abbrev": "SST",
#             "id": 28,
#             "owners": [
#                 "{42821CD5-BA25-4673-9863-BD982302659E}"
#             ]
#         },
#         {
#             "abbrev": "Doug",
#             "id": 29,
#             "owners": [
#                 "{B300EFB4-C4B0-4489-B223-2BBEC1C9457C}"
#             ]
#         },
#         {
#             "abbrev": "DPC",
#             "id": 30,
#             "owners": [
#                 "{20B775B5-5DAB-4BE2-B775-B55DAB6BE219}",
#                 "{65AD150C-B32C-4287-A731-35F5DEF5B065}"
#             ]
#         },
#         {
#             "abbrev": "BDS",
#             "id": 31,
#             "owners": [
#                 "{412D7913-5D28-4A74-9F7C-092F3E53494F}",
#                 "{D0F9919A-5E9C-418A-952D-9A13A733B299}"
#             ]
#         },
#         {
#             "abbrev": "NNT",
#             "id": 32,
#             "owners": [
#                 "{B98F7BCE-BF36-4468-A2D3-CADAC71E27DA}"
#             ]
#         },
#         {
#             "abbrev": "RRT",
#             "id": 33,
#             "owners": [
#                 "{692022BB-7549-4974-9FC6-3CFF1B45C1A3}"
#             ]
#         },
#         {
#             "abbrev": "1962",
#             "id": 34,
#             "owners": [
#                 "{371C6056-332E-4B78-A748-A89028896967}"
#             ]
#         },
#         {
#             "abbrev": "Roth",
#             "id": 35,
#             "owners": [
#                 "{643CBCDA-3840-4DD6-BCBC-DA38404DD68F}"
#             ]
#         },
#         {
#             "abbrev": "FEST",
#             "id": 36,
#             "owners": [
#                 "{854E312A-BC0C-4C3B-8E31-2ABC0C5C3BDE}"
#             ]
#         }
#     ]
# }
